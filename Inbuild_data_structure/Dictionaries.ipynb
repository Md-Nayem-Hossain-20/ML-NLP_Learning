# %% [markdown]
# ## Dictionaries
#
# Dictionaries are unordered collection of items. They store data in key_value pairs. Keys must be unique and immutable (e.g., strings, numbers or tuples) while values can be of any type.

# %%
## Creating dictionaries

empty_dict = {}
print(type(empty_dict))
