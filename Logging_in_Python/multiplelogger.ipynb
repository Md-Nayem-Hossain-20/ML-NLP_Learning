# %% [markdown]
# # Logging with multiple Loggers
#
# You can create multiple loggers for different parts of applications.

# %%
import logging

# Create a logger for module1

logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

# Create a logger for moduler2

logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)


logging.basicConfig(
    level = logging.DEBUG,
    format = '%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt = '%Y-%m-%d %H:%M:%S',
    force = True
)

# %%
# log message with different loggers

logger1.debug("This is debug message for module1")
logger2.warning("This is a warning message for module2")
logger2.error("This is an error message for module1")
# Out:
# 2026-01-03 16:35:54-module1-DEBUG-This is debug message for module1
# 2026-01-03 16:35:54-module2-WARNING-This is a warning message for module2
# 2026-01-03 16:35:54-module2-ERROR-This is an error message for module1
