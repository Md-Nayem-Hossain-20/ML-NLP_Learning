# %%
## Integers Example

age = 35

type(age)
# Out:
# int

# %%
## Floating point data type

height = 5.5

print(type(height))
# Out:
# <class 'float'>

# %%
## String

name = "Nayem"

print(type(name))
# Out:
# <class 'str'>

# %%
## Boolean data type

is_true = True

type(is_true)
# Out:
# bool

# %%
bool()
# Out:
# False

# %%
a = 10
b = 12

type(a==b)
# Out:
# bool
