# %% [markdown]
# ## Basic Syntax In Python
#
# ### Case sensitivity - Python is case sensitive

# %%
name = "Nayem"
Name = "Hossain"

print(name)
print(Name)
# Out:
# Nayem
# Hossain

# %% [markdown]
# ### Indentation
# #### Python uses indentation to define blocks of code. Consistent use of spaces (commonly 4) or a tab is required.

# %%
age = 25

if age > 20:
    print(age)

print(age)
# Out:
# 25
# 25

# %%
## This is a Single line comment.

print("Hello World!")
# Out:
# Hello World!

# %%
## Line continuation

total = 1+2+3+4+5+6+7+\
4+5

print(total)
# Out:
# 37

# %%
## Multiple statement in a single line

x=4; y=5; z=x+y

print(z)
# Out:
# 9

# %%
## Understand sementics 

## Variable Assignment

age = 25   # age is an integer
name = "Nayem"  # name is a string

type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
# Type interface

print(type(name))
# Out:
# <class 'str'>

# %%
## Code examples of indentations

if True:
    print("Correct Indentation")
    if False:
        print("This won't print")
    print("This will Print.")

print("Outside the if blocks.")
# Out:
# Correct Indentation
# This will Print.
# Outside the if blocks.
